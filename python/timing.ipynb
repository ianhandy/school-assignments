# %%
import numpy as np
import math as m

# %%
test_array = list(range[1000000])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_array = [i for i in np.arange[1000000]]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
numpy_time = np.sin(test_array)

# %%
for_time = [m.sin(i) for i in test_array]
